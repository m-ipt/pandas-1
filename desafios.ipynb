# %% [markdown]
# ## Descrição
#
# Esse notebook foi construído para realizar os desafios propostos no final de cada aula do curso **Pandas: conhecendo a biblioteca**

# %% [markdown]
# ## Aula 1: Conhecendo a base de dados

# %% [markdown]
# ### Desafio 1
# Importe o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) e armazene seu conteúdo em um DataFrame Pandas

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 2
# Visualize as primeiras 7 linhas do DataFrame e as 5 últimas

# %%
dados = pd.read_csv(url)
dados

dados.head(7)
# Out:
#     Nome  Idade  Notas  Aprovado
# 0    Ary     20    7.5      True
# 1    Ana     18    NaN     False
# 2  Cátia     27    2.5     False
# 3  Denis     18    5.0     False
# 4   Beto     21   10.0      True
# 5  Bruna     23    NaN     False
# 6   Dara     21    7.0      True

# %%
dados.tail()
# Out:
#       Nome  Idade  Notas  Aprovado
# 13   Mirla     25    9.0      True
# 14   Paulo     37    NaN     False
# 15  Mylena     29    7.0      True
# 16   Lucas     33    NaN     False
# 17   Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Confira a quantidade de linhas e colunas do DataFrame

# %%
dados.shape
# Out:
# (18, 4)

# %% [markdown]
# ### Desafio 4
# Explore as colunas do DataFrame e analise os tipos dos dados presentes em cada coluna

# %%
dados['Nome']
# Out:
# 0           Ary
# 1           Ana
# 2         Cátia
# 3         Denis
# 4          Beto
# 5         Bruna
# 6          Dara
# 7        Carlos
# 8         Alice
# 9         Vitor
# 10       Daniel
# 11         Igor
# 12    Sthefanie
# 13        Mirla
# 14        Paulo
# 15       Mylena
# 16        Lucas
# 17        Nadia
# Name: Nome, dtype: object

# %%
dados['Idade']
# Out:
# 0     20
# 1     18
# 2     27
# 3     18
# 4     21
# 5     23
# 6     21
# 7     19
# 8     35
# 9     28
# 10    21
# 11    24
# 12    26
# 13    25
# 14    37
# 15    29
# 16    33
# 17    34
# Name: Idade, dtype: int64

# %%
dados['Notas']
# Out:
# 0      7.5
# 1      NaN
# 2      2.5
# 3      5.0
# 4     10.0
# 5      NaN
# 6      7.0
# 7      6.0
# 8      5.6
# 9      NaN
# 10     NaN
# 11     4.5
# 12     9.5
# 13     9.0
# 14     NaN
# 15     7.0
# 16     NaN
# 17     8.0
# Name: Notas, dtype: float64

# %%
dados['Notas']
# Out:
# 0      7.5
# 1      NaN
# 2      2.5
# 3      5.0
# 4     10.0
# 5      NaN
# 6      7.0
# 7      6.0
# 8      5.6
# 9      NaN
# 10     NaN
# 11     4.5
# 12     9.5
# 13     9.0
# 14     NaN
# 15     7.0
# 16     NaN
# 17     8.0
# Name: Notas, dtype: float64

# %% [markdown]
# ### **Extra**
# Calcule algumas estatísticas descritivas básicas dos dados do DataFrame (média, desvio padrão, etc) - Dica: pesquise pelo método **describe**

# %%
dados.describe()
# Out:
#            Idade      Notas
# count  18.000000  12.000000
# mean   25.500000   6.800000
# std     6.070662   2.204953
# min    18.000000   2.500000
# 25%    21.000000   5.450000
# 50%    24.500000   7.000000
# 75%    28.750000   8.250000
# max    37.000000  10.000000

# %% [markdown]
# ## Aula 2: Análise exploratória dos dados

# %% [markdown]
# Para os desafios dessa aula, vamos utilizar a mesma base de dados que estamos utilizando para o desenvolvimento do nosso projeto. Sendo assim, na célula abaixo vamos realizar a importação dessa base de dados e aplicar as transformações já realizadas até o momento da aula 2.

# %%
import pandas as pd

# %%
# importando a base de dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/base-de-dados/aluguel.csv'
dados = pd.read_csv(url, sep=';')

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala',
                      'Prédio Inteiro', 'Loja/Salão',
                      'Galpão/Depósito/Armazém',
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# removendo imóveis comerciais
df = dados.query('@imoveis_comerciais not in Tipo')

# selecionando apenas imóveis do tipo apartamento
df = df.query('Tipo == "Apartamento"')

# visualizando a base de dados
df.head()
# Out:
#            Tipo        Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 3   Apartamento        Centro        1      0       0    15   800.0
# 4   Apartamento  Higienópolis        1      0       0    48   800.0
# 5   Apartamento  Vista Alegre        3      1       0    70  1200.0
# 6   Apartamento      Cachambi        2      0       0    50  1300.0
# 10  Apartamento        Centro        1      0       0    36  1200.0
#
#     Condominio  IPTU
# 3        390.0  20.0
# 4        230.0   NaN
# 5          NaN   NaN
# 6        301.0  17.0
# 10         NaN   NaN

# %% [markdown]
# ### Desafio 1
# Calcular a média de quartos por apartamento

# %%
df['Quartos'].mean()
# Out:
# 2.481568707761622

# %% [markdown]
# ### Desafio 2
# Conferir quantos bairros únicos existem na nossa base de dados

# %%
len(df['Bairro'].unique())
# Out:
# 149

# %%
df['Bairro'].nunique()
# Out:
# 149

# %% [markdown]
# ### Desafio 3
# Analisar quais bairros possuem a média de valor de aluguel mais elevadas

# %%
df.groupby('Bairro')[['Valor']].mean().sort_values('Valor').tail()

# Resposta da instrutora:
# df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False)
# Na minha resposta mostra
# Out:
#                       Valor
# Bairro
# Botafogo        9369.207116
# Ipanema         9487.205317
# Cidade Jardim  12000.000000
# Arpoador       12429.769231
# Joá            15500.000000

# %% [markdown]
# ### Desafio 4
# Criar um gráfico de barras verticais que apresente os 5 bairros com a média de valor de aluguel mais elevadas

# %%
df_bairros = df.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False).head()

# %%
df_bairros = dados.groupby('Bairro')[['Valor']].mean().sort_values('Valor', ascending=False).head()

df_bairros.plot(kind='barh', figsize=(14, 10), color ='purple')
# Out:
# <Axes: ylabel='Bairro'>

# %% [markdown]
# ## Aula 3
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
# Importando novamente os dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 1
# Verifique se a base de dados possui dados nulos e caso tenha, realize o tratamento desses dados nulos

# %%
notas = pd.read_csv(url)

# %%
notas.isnull()
# Out:
#      Nome  Idade  Notas  Aprovado
# 0   False  False  False     False
# 1   False  False   True     False
# 2   False  False  False     False
# 3   False  False  False     False
# 4   False  False  False     False
# 5   False  False   True     False
# 6   False  False  False     False
# 7   False  False  False     False
# 8   False  False  False     False
# 9   False  False   True     False
# 10  False  False   True     False
# 11  False  False  False     False
# 12  False  False  False     False
# 13  False  False  False     False
# 14  False  False   True     False
# 15  False  False  False     False
# 16  False  False   True     False
# 17  False  False  False     False

# %%
notas = notas.fillna(0)
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 2
# Os alunos "Alice" e "Carlos", não fazem mais parte da turma. Sendo assim, remova-os da base de dados

# %%
notas.query('Nome == "Alice" | Nome == "Carlos"').index
# Out:
# Int64Index([7, 8], dtype='int64')

# %%
alunos_a_remover = notas.query('Nome == "Alice" | Nome == "Carlos"').index

# %%
notas.drop(alunos_a_remover, axis=0, inplace=True)

# %%
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 3
# Aplique um filtro que selecione apenas os alunos que foram aprovados

# %%
notas['Aprovado'] == True
# Out:
# 0      True
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 9     False
# 10    False
# 11    False
# 12     True
# 13     True
# 14    False
# 15     True
# 16    False
# 17     True
# Name: Aprovado, dtype: bool

# %%
aprovados = notas['Aprovado'] == True
notas[aprovados]
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 4        Beto     21   10.0      True
# 6        Dara     21    7.0      True
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 15     Mylena     29    7.0      True
# 17      Nadia     34    8.0      True

# %% [markdown]
# ### Desafio 4
# Salve o DataFrame que possui apenas os alunos aprovados em um arquivo csv chamado "alunos_aprovados.csv"

# %%
notas[aprovados].to_csv('alunos_aprovados.csv')

# %%
pd.read_csv('alunos_aprovados.csv')
# Out:
#    Unnamed: 0       Nome  Idade  Notas  Aprovado
# 0           0        Ary     20    7.5      True
# 1           4       Beto     21   10.0      True
# 2           6       Dara     21    7.0      True
# 3          12  Sthefanie     26    9.5      True
# 4          13      Mirla     25    9.0      True
# 5          15     Mylena     29    7.0      True
# 6          17      Nadia     34    8.0      True

# %% [markdown]
# ### **Extra**
# Ao conferir as notas dos alunos aprovados, notamos que algumas notas estavam incorretas. As alunas que tiraram nota 7.0, na verdade tinham um ponto extra que não foi contabilizado. Sendo assim, substitua as notas 7.0 da base de dados por 8.0. **Dica**: pesquise pelo método **replace**

# %%
notas.query('Notas == 7.0')
# Out:
#       Nome  Idade  Notas  Aprovado
# 6     Dara     21    7.0      True
# 15  Mylena     29    7.0      True

# %%
notas_atualizadas = notas.replace(7, 8)

# %%
notas_atualizadas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    8.0      True
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    8.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %% [markdown]
# ## Aula 4
#
# Importe novamente o arquivo [**alunos.csv**](https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv) para realizar os desafios abaixo.

# %%
import pandas as pd

# Importando novamente os dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
notas = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'

# %% [markdown]
# ### Desafio 1
# Os alunos participaram de uma atividade extracurricular e ganharam pontos extras. Esses pontos extras correspondem a 40% da nota atual de cada um deles. Com base nisso, crie uma coluna chamada "Pontos_extras" que contenha os pontos extras de cada aluno, ou seja, 40% da nota atual deles

# %%
import pandas as pd

# Importando novamente os dados
url = 'https://raw.githubusercontent.com/alura-cursos/pandas-conhecendo-a-biblioteca/main/desafios/alunos.csv'
pd.read_csv(url)
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    NaN     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    NaN     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    NaN     False
# 10     Daniel     21    NaN     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    NaN     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    NaN     False
# 17      Nadia     34    8.0      True

# %%
notas = pd.read_csv(url)

# %%
notas = notas.fillna(0)
notas
# Out:
#          Nome  Idade  Notas  Aprovado
# 0         Ary     20    7.5      True
# 1         Ana     18    0.0     False
# 2       Cátia     27    2.5     False
# 3       Denis     18    5.0     False
# 4        Beto     21   10.0      True
# 5       Bruna     23    0.0     False
# 6        Dara     21    7.0      True
# 7      Carlos     19    6.0      True
# 8       Alice     35    5.6     False
# 9       Vitor     28    0.0     False
# 10     Daniel     21    0.0     False
# 11       Igor     24    4.5     False
# 12  Sthefanie     26    9.5      True
# 13      Mirla     25    9.0      True
# 14      Paulo     37    0.0     False
# 15     Mylena     29    7.0      True
# 16      Lucas     33    0.0     False
# 17      Nadia     34    8.0      True

# %%
notas['Pontos_extras'] = notas['Notas'].apply(lambda x: 0.4 * x)
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras
# 0         Ary     20    7.5      True           3.00
# 1         Ana     18    0.0     False           0.00
# 2       Cátia     27    2.5     False           1.00
# 3       Denis     18    5.0     False           2.00
# 4        Beto     21   10.0      True           4.00
# 5       Bruna     23    0.0     False           0.00
# 6        Dara     21    7.0      True           2.80
# 7      Carlos     19    6.0      True           2.40
# 8       Alice     35    5.6     False           2.24
# 9       Vitor     28    0.0     False           0.00
# 10     Daniel     21    0.0     False           0.00
# 11       Igor     24    4.5     False           1.80
# 12  Sthefanie     26    9.5      True           3.80
# 13      Mirla     25    9.0      True           3.60
# 14      Paulo     37    0.0     False           0.00
# 15     Mylena     29    7.0      True           2.80
# 16      Lucas     33    0.0     False           0.00
# ...

# %% [markdown]
# ### Desafio 2
# Crie mais uma coluna, chamada "Notas_finais" que possua as notas de cada aluno somada com os pontos extras

# %%
notas['Notas_finais'] = notas['Notas'] + notas['Pontos_extras']
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# ### Desafio 3
# Como os alunos ganharam pontos extras, alguns que não tinham sido aprovados antes podem ter sido aprovados agora. Com base nisso, crie uma coluna chamada "Aprovado_final" com os seguintes valores:
#
# * True: caso o aluno esteja aprovado (nota final deve ser maior ou igual a 6);
# * False: caso o aluno esteja reprovado (nota final deve ser menor que 6).

# %%
notas['Aprovado_final'] = notas['Notas_finais'].apply(lambda x: "True" if x >= 6 else "False")
notas
# Out:
#          Nome  Idade  Notas  Aprovado  Pontos_extras  Notas_finais  \
# 0         Ary     20    7.5      True           3.00         10.50
# 1         Ana     18    0.0     False           0.00          0.00
# 2       Cátia     27    2.5     False           1.00          3.50
# 3       Denis     18    5.0     False           2.00          7.00
# 4        Beto     21   10.0      True           4.00         14.00
# 5       Bruna     23    0.0     False           0.00          0.00
# 6        Dara     21    7.0      True           2.80          9.80
# 7      Carlos     19    6.0      True           2.40          8.40
# 8       Alice     35    5.6     False           2.24          7.84
# 9       Vitor     28    0.0     False           0.00          0.00
# 10     Daniel     21    0.0     False           0.00          0.00
# 11       Igor     24    4.5     False           1.80          6.30
# 12  Sthefanie     26    9.5      True           3.80         13.30
# ...

# %% [markdown]
# ### Desafio 4
# Faça uma seleção e verifique quais alunos não tinham sido aprovados anteriormente, mas foram aprovados após a soma dos pontos extras

# %%
notas.query('Aprovado == False & Aprovado_final == True')
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado, Pontos_extras, Notas_finais, Aprovado_final]
# Index: []

# %%
selecao = (notas['Aprovado'] == False) & (notas['Aprovado_final'] == True)
notas[selecao]
# Out:
# Empty DataFrame
# Columns: [Nome, Idade, Notas, Aprovado, Pontos_extras, Notas_finais, Aprovado_final]
# Index: []
